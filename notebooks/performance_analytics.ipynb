# %% [markdown]
#  Performance Analytics
#
# This notebook calculates key mutual fund performance metrics:
#
# - CAGR
# - Sharpe Ratio
# - Sortino Ratio
# - Maximum Drawdown
# - Tracking Error

# %%
import pandas as pd

# %%
cagr_df = pd.read_csv("../data/processed/cagr_results.csv")
cagr_df.head()
# Out:
#    amfi_code  start_nav  end_nav  years  cagr_pct
# 0     100016     520.46   583.61    4.4      2.64
# 1     100025      26.32    31.88    4.4      4.46
# 2     100033     107.38   342.01    4.4     30.12
# 3     101206     305.10   773.29    4.4     23.54
# 4     101207      38.57    53.98    4.4      7.94

# %% [markdown]
# CAGR Analysis

# %%
cagr_df.describe()
# Out:
#            amfi_code    start_nav      end_nav  years   cagr_pct
# count      40.000000    40.000000    40.000000   40.0  40.000000
# mean   120247.000000   207.213750   357.612750    4.4  16.735500
# std     14534.998667   499.020345   675.882091    0.0  10.308558
# min    100016.000000    26.320000    31.880000    4.4   1.170000
# 25%    118632.750000    51.867500   103.545000    4.4   6.865000
# 50%    119551.500000    80.070000   188.070000    4.4  16.605000
# 75%    120842.250000   175.522500   381.375000    4.4  24.487500
# max    149324.000000  3180.630000  4268.550000    4.4  32.830000

# %%
sharpe_df = pd.read_csv("../data/processed/sharpe_ratios.csv")
sharpe_df.head()
# Out:
#    amfi_code  annual_return  annual_volatility  sharpe_ratio
# 0     100016         0.0357             0.1455       -0.2015
# 1     100025         0.0429             0.0391       -0.5671
# 2     100033         0.2721             0.1894        1.0937
# 3     101206         0.2146             0.1457        1.0272
# 4     101207         0.1070             0.2580        0.1627

# %%
sortino_df = pd.read_csv("../data/processed/sortino_ratios.csv")
sortino_df.head()
# Out:
#    amfi_code  annual_return  downside_deviation  sortino_ratio
# 0     100016         0.0357              0.0835        -0.3510
# 1     100025         0.0429              0.0235        -0.9418
# 2     100033         0.2721              0.1132         1.8291
# 3     101206         0.2146              0.0832         1.7996
# 4     101207         0.1070              0.1517         0.2766

# %%
mdd_df = pd.read_csv("../data/processed/max_drawdown_results.csv")
mdd_df.head()
# Out:
#    amfi_code  max_drawdown_pct
# 0     100016            -24.73
# 1     100025             -4.31
# 2     100033            -16.22
# 3     101206            -11.29
# 4     101207            -35.45
